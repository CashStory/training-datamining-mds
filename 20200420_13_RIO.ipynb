# %% [markdown]
# <a href="https://colab.research.google.com/github/Warziikx/training-datamining-mds/blob/master/20200420_13_RIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly==4.6.0
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
# Out:
# Collecting plotly==4.6.0
#   Downloading https://files.pythonhosted.org/packages/15/90/918bccb0ca60dc6d126d921e2c67126d75949f5da777e6b18c51fb12603d/plotly-4.6.0-py2.py3-none-any.whl (7.1MB)
#      |████████████████████████████████| 7.2MB 4.6MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly==4.6.0) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly==4.6.0) (1.12.0)
# Installing collected packages: plotly
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# Successfully installed plotly-4.6.0

# %%
data = pd.read_excel('https://population.un.org/wup/Download/Files/WUP2018-F01-Total_Urban_Rural.xls',skiprows = 29, header=None,)
data
# Out:
#        0                          1   2  ...           5            6          7
# 0     13                     AFRICA NaN  ...  740318.336  1287920.518  42.518321
# 1     14             Eastern Africa NaN  ...  312327.611   433643.132  27.975889
# 2     15                    Burundi NaN  ...    9754.746    11216.450  13.031788
# 3     16                    Comoros NaN  ...     591.255      832.347  28.965323
# 4     17                   Djibouti NaN  ...     215.875      971.408  77.777103
# ..   ...                        ...  ..  ...         ...          ...        ...
# 256  269                      Samoa NaN  ...     161.629      197.695  18.243253
# 257  270                    Tokelau NaN  ...       1.319        1.319   0.000000
# 258  271                      Tonga NaN  ...      83.793      109.008  23.131330
# 259  272                     Tuvalu NaN  ...       4.245       11.287  62.390361
# 260  273  Wallis and Futuna Islands NaN  ...      11.683       11.683   0.000000
#
# [261 rows x 8 columns]

# %%
countriesAndRegions = data[1].tolist()
countriesAndRegions
OrderedDatas = []
continents = []
numberOfContinents = 0
continentName = ''

for countrieAndRegion in countriesAndRegions:
  index = data[1].tolist().index(countrieAndRegion)
  if (data[3][index] != 5500 and data[3][index] != 5501):
    if (countrieAndRegion.isupper()):
      continent = {}
      continentName = countrieAndRegion.lower().capitalize()
      continent['name'] = continentName
      continent['urbanPop'] = data[4][index]
      continent['ruralPop'] = data[5][index]
      continent['percent'] = float(round(data[7][index], 1))
      continent['totalPop'] = data[6][index]
      continent['childs'] = []
      continents.append(continent)
    elif (data[3][index] >= 900):
      region = {}
      regionName = countrieAndRegion
      region['name'] = regionName
      region['urbanPop'] = data[4][index]
      region['ruralPop'] = data[5][index]
      region['percent'] = float(round(data[7][index], 1))
      region['totalPop'] = data[6][index]
      region['childs'] = []
      for continentFinal in continents:
        if (continentFinal.get('name') == continentName):
          continentChilds = continentFinal.get('childs')
          continentChilds.append(region)
    else :
      country = {} 
      country['name'] = countrieAndRegion
      country['urbanPop'] = data[4][index]
      country['ruralPop'] = data[5][index]
      country['totalPop'] = data[6][index]
      country['percent'] = float(round(data[7][index], 1))
      for continentFinal in continents:
        if (continentFinal.get('name') == continentName):
          regions = continentFinal.get('childs')
          if (continentFinal.get('name')  == 'Northern america'):
                regions.append(country)
          else:
            for regionFinal in regions:
              if (regionFinal.get('name') == regionName):
                regionChilds = regionFinal.get('childs')
                regionChilds.append(country)


continents[1]
# Out:
# {'childs': [{'childs': [{'name': 'China',
#      'percent': 59.2,
#      'ruralPop': 578023.833,
#      'totalPop': 1415045.928,
#      'urbanPop': 837022.095},
#     {'name': 'China, Hong Kong SAR',
#      'percent': 100.0,
#      'ruralPop': 0.0,
#      'totalPop': 7428.887,
#      'urbanPop': 7428.887},
#     {'name': 'China, Macao SAR',
#      'percent': 100.0,
#      'ruralPop': 0.0,
#      'totalPop': 632.418,
#      'urbanPop': 632.418},
#     {'name': 'China, Taiwan Province of China',
#      'percent': 78.2,
#      'ruralPop': 5175.798,
#      'totalPop': 23694.089,
#      'urbanPop': 18518.291},
#     {'name': "Dem. People's Republic of Korea",
#      'percent': 61.9,
#      'ruralPop': 9757.856,
#      'totalPop': 25610.672,
#      'urbanPop': 15852.816},
#     {'name': 'Japan',
#      'percent': 91.6,
#      'ruralPop': 10663.807,
#      'totalPop': 127185.332,
#      'urbanPop': 116521.525},
#     {'name': 'Mongolia',
#      'percent': 68.4,
#      'ruralPop': 985.062,
#      'totalPop': 3121.772,
#      'urbanPop': 2136.71},
#     {'name': 'Republic of Korea',
#      'percent': 81.5,
#      'ruralPop': 9486.209,
#      'totalPop': 51164.435,
#      'urbanPop': 41678.226}],
#    'name': 'Eastern Asia',
#    'percent': 62.9,
#    'ruralPop': 614092.5650000004,
#    'totalPop': 1653883.5330000003,
#    'urbanPop': 1039790.9679999999},
#   {'childs': [{'name': 'Kazakhstan',
#      'percent': 57.4,
#      'ruralPop': 7834.88,
#      'totalPop': 18403.86,
#      'urbanPop': 10568.98},
#     {'name': 'Kyrgyzstan',
#      'percent': 36.4,
#      'ruralPop': 3903.563,
#      'totalPop': 6132.932,
#      'urbanPop': 2229.369},
#     {'name': 'Tajikistan',
#      'percent': 27.1,
#      'ruralPop': 6636.026,
#      'totalPop': 9107.211,
#      'urbanPop': 2471.185},
#     {'name': 'Turkmenistan',
#      'percent': 51.6,
#      'ruralPop': 2832.499,
#      'totalPop': 5851.466,
#      'urbanPop': 3018.967},
#     {'name': 'Uzbekistan',
#      'percent': 50.5,
#      'ruralPop': 16027.774,
#      'totalPop': 32364.996,
#      'urbanPop': 16337.222},
#     {'name': 'Afghanistan',
#      'percent': 25.5,
#      'ruralPop': 27099.874,
#      'totalPop': 36373.176,
#      'urbanPop': 9273.302},
#     {'name': 'Bangladesh',
#      'percent': 36.6,
#      'ruralPop': 105423.904,
#      'totalPop': 166368.149,
#      'urbanPop': 60944.245},
#     {'name': 'Bhutan',
#      'percent': 40.9,
#      'ruralPop': 482.916,
#      'totalPop': 817.054,
#      'urbanPop': 334.138},
#     {'name': 'India',
#      'percent': 34.0,
#      'ruralPop': 893272.09,
#      'totalPop': 1354051.854,
#      'urbanPop': 460779.764},
#     {'name': 'Iran (Islamic Republic of)',
#      'percent': 74.9,
#      'ruralPop': 20586.68,
#      'totalPop': 82011.735,
#      'urbanPop': 61425.055},
#     {'name': 'Maldives',
#      'percent': 39.8,
#      'ruralPop': 267.408,
#      'totalPop': 444.259,
#      'urbanPop': 176.851},
#     {'name': 'Nepal',
#      'percent': 19.7,
#      'ruralPop': 23776.364,
#      'totalPop': 29624.035,
#      'urbanPop': 5847.671},
#     {'name': 'Pakistan',
#      'percent': 36.7,
#      'ruralPop': 127183.388,
#      'totalPop': 200813.818,
#      'urbanPop': 73630.43},
#     {'name': 'Sri Lanka',
#      'percent': 18.5,
#      'ruralPop': 17079.399,
#      'totalPop': 20950.041,
#      'urbanPop': 3870.642}],
#    'name': 'South-Central Asia',
#    'percent': 36.2,
#    'ruralPop': 1252406.7650000001,
#    'totalPop': 1963314.5860000001,
#    'urbanPop': 710907.821},
#   {'childs': [{'name': 'Brunei Darussalam',
#      'percent': 77.6,
#      'ruralPop': 97.106,
#      'totalPop': 434.076,
#      'urbanPop': 336.97},
#     {'name': 'Cambodia',
#      'percent': 23.4,
#      'ruralPop': 12446.208,
#      'totalPop': 16245.729,
#      'urbanPop': 3799.521},
#     {'name': 'Indonesia',
#      'percent': 55.3,
#      'ruralPop': 119191.974,
#      'totalPop': 266794.98,
#      'urbanPop': 147603.006},
#     {'name': "Lao People's Democratic Republic",
#      'percent': 35.0,
#      'ruralPop': 4524.499,
#      'totalPop': 6961.21,
#      'urbanPop': 2436.711},
#     {'name': 'Malaysia',
#      'percent': 76.0,
#      'ruralPop': 7678.728,
#      'totalPop': 32042.458,
#      'urbanPop': 24363.73},
#     {'name': 'Myanmar',
#      'percent': 30.6,
#      'ruralPop': 37387.374,
#      'totalPop': 53855.735,
#      'urbanPop': 16468.361},
#     {'name': 'Philippines',
#      'percent': 46.9,
#      'ruralPop': 56550.096,
#      'totalPop': 106512.074,
#      'urbanPop': 49961.978},
#     {'name': 'Singapore',
#      'percent': 100.0,
#      'ruralPop': 0.0,
#      'totalPop': 5791.901,
#      'urbanPop': 5791.901},
#     {'name': 'Thailand',
#      'percent': 49.9,
#      'ruralPop': 34627.095,
#      'totalPop': 69183.173,
#      'urbanPop': 34556.078},
#     {'name': 'Timor-Leste',
#      'percent': 30.6,
#      'ruralPop': 919.214,
#      'totalPop': 1324.094,
#      'urbanPop': 404.88},
#     {'name': 'Viet Nam',
#      'percent': 35.9,
#      'ruralPop': 61832.185,
#      'totalPop': 96491.146,
#      'urbanPop': 34658.961}],
#    'name': 'South-Eastern Asia',
#    'percent': 48.9,
#    'ruralPop': 335254.4789999999,
#    'totalPop': 655636.5759999999,
#    'urbanPop': 320382.097},
#   {'childs': [{'name': 'Armenia',
#      'percent': 63.1,
#      'ruralPop': 1081.275,
#      'totalPop': 2934.152,
#      'urbanPop': 1852.877},
#     {'name': 'Azerbaijan',
#      'percent': 55.7,
#      'ruralPop': 4398.268,
#      'totalPop': 9923.914,
#      'urbanPop': 5525.646},
#     {'name': 'Bahrain',
#      'percent': 89.3,
#      'ruralPop': 167.867,
#      'totalPop': 1566.993,
#      'urbanPop': 1399.126},
#     {'name': 'Cyprus',
#      'percent': 66.8,
#      'ruralPop': 394.652,
#      'totalPop': 1189.085,
#      'urbanPop': 794.433},
#     {'name': 'Georgia',
#      'percent': 58.6,
#      'ruralPop': 1616.295,
#      'totalPop': 3907.131,
#      'urbanPop': 2290.836},
#     {'name': 'Iraq',
#      'percent': 70.5,
#      'ruralPop': 11615.946,
#      'totalPop': 39339.753,
#      'urbanPop': 27723.807},
#     {'name': 'Israel',
#      'percent': 92.4,
#      'ruralPop': 640.922,
#      'totalPop': 8452.841,
#      'urbanPop': 7811.919},
#     {'name': 'Jordan',
#      'percent': 91.0,
#      'ruralPop': 893.429,
#      'totalPop': 9903.802,
#      'urbanPop': 9010.373},
#     {'name': 'Kuwait',
#      'percent': 100.0,
#      'ruralPop': 0.0,
#      'totalPop': 4197.128,
#      'urbanPop': 4197.128},
#     {'name': 'Lebanon',
#      'percent': 88.6,
#      'ruralPop': 695.098,
#      'totalPop': 6093.509,
#      'urbanPop': 5398.411},
#     {'name': 'Oman',
#      'percent': 84.5,
#      'ruralPop': 746.74,
#      'totalPop': 4829.946,
#      'urbanPop': 4083.206},
#     {'name': 'Qatar',
#      'percent': 99.1,
#      'ruralPop': 23.303,
#      'totalPop': 2694.849,
#      'urbanPop': 2671.546},
#     {'name': 'Saudi Arabia',
#      'percent': 83.8,
#      'ruralPop': 5421.205,
#      'totalPop': 33554.343,
#      'urbanPop': 28133.138},
#     {'name': 'State of Palestine',
#      'percent': 76.2,
#      'ruralPop': 1204.356,
#      'totalPop': 5052.776,
#      'urbanPop': 3848.42},
#     {'name': 'Syrian Arab Republic',
#      'percent': 54.2,
#      'ruralPop': 8381.17,
#      'totalPop': 18284.407,
#      'urbanPop': 9903.237},
#     {'name': 'Turkey',
#      'percent': 75.1,
#      'ruralPop': 20362.183,
#      'totalPop': 81916.871,
#      'urbanPop': 61554.688},
#     {'name': 'United Arab Emirates',
#      'percent': 86.5,
#      'ruralPop': 1285.972,
#      'totalPop': 9541.615,
#      'urbanPop': 8255.643},
#     {'name': 'Yemen',
#      'percent': 36.6,
#      'ruralPop': 18320.024,
#      'totalPop': 28915.284,
#      'urbanPop': 10595.26}],
#    'name': 'Western Asia',
#    'percent': 71.6,
#    'ruralPop': 77248.70499999996,
#    'totalPop': 272298.399,
#    'urbanPop': 195049.69400000002}],
#  'name': 'Asia',
#  'percent': 49.9,
#  'ruralPop': 2279002.5140000004,
#  'totalPop': 4545133.0940000005,
#  'urbanPop': 2266130.58}

# %% [markdown]
# **Format de sortie du tableau continents pour un continent**
#
#
# ```
# [
#   #continent
#   {
#     name: ,
#     urbanPop: ,
#     ruralPop: ,
#     percent: ,
#     childs: [
#       #region
#       {
#         name: ,
#         urbanPop: ,
#         ruralPop: ,
#         percent: ,
#         childs: [
#           #country
#           {
#             name: ,
#             urbanPop: ,
#             ruralPop: ,
#             percent: ,
#           }
#         ]
#       }
#     ]
#   }
# ]
# ```

# %%
characters = ["World"]
parents = [""]
values = [7632819.325]
percents = [55.3]
for continent in continents:
  parents.append('World')
  characters.append(continent.get('name'))
  values.append(continent.get('totalPop'))
  percents.append(continent.get('percent'))
  for region in continent.get('childs'):
    parents.append(continent.get('name'))
    characters.append(region.get('name'))
    values.append(region.get('totalPop'))
    percents.append(region.get('percent'))
    if (region.get('childs') is not None):
      for country in region.get('childs'):
        if((country.get('totalPop') /region.get('totalPop') * 100) < 10):
          if(region.get('name') + " smallest country" not in characters):
            parents.append(region.get('name'))
            characters.append(region.get('name') + " smallest country")

            smallTotalPop = 0
            nbOfSmallCountry = 0
            smallUrbanPercent = 0
            print(region.get('name'))
            print(country.get('name'))
            for country2 in region.get('childs'):
              if((country2.get('totalPop') /region.get('totalPop') * 100) < 10):
                print("pop + " + str(country2.get('totalPop')))
                smallTotalPop += country2.get('totalPop')
                nbOfSmallCountry += 1
                smallUrbanPercent += country2.get('percent')
            values.append(smallTotalPop)
            print("total  : " + str(smallTotalPop))
            print("End")
            percents.append(float(round(smallUrbanPercent / nbOfSmallCountry,1)))
          parents.append(region.get('name') + " smallest country")
          characters.append(country.get('name'))
          values.append(country.get('totalPop'))
          percents.append(country.get('percent'))
        else:
          parents.append(region.get('name'))
          characters.append(country.get('name'))
          values.append(country.get('totalPop'))
          percents.append(country.get('percent'))




stubData = dict(
    parent = parents,
    character = characters,
    value = values,
    urban = percents
  )
# Out:
# Eastern Africa
# Burundi
# pop + 11216.45
# pop + 832.347
# pop + 971.408
# pop + 5187.948
# pop + 26262.81
# pop + 19164.728
# pop + 1268.315
# pop + 259.682
# pop + 30528.673
# pop + 883.247
# pop + 12501.156
# pop + 95.235
# pop + 15181.925
# pop + 12919.053
# pop + 17609.178
# pop + 16913.261
# total  : 171795.41600000003
# End
# Middle Africa
# Central African Republic
# pop + 4737.423
# pop + 15353.184
# pop + 5399.895
# pop + 1313.894
# pop + 2067.561
# pop + 208.818
# total  : 29080.775
# End
# Northern Africa
# Libya
# pop + 6470.956
# pop + 11659.174
# pop + 567.421
# total  : 18697.551
# End
# Southern Africa
# Botswana
# pop + 2333.201
# pop + 2263.01
# pop + 2587.801
# pop + 1391.385
# total  : 8575.397
# End
# Western Africa
# Benin
# pop + 11485.674
# pop + 19751.651
# pop + 553.335
# pop + 24905.843
# pop + 2163.765
# pop + 29463.643
# pop + 13052.608
# pop + 1907.268
# pop + 4853.516
# pop + 19107.706
# pop + 4540.068
# pop + 22311.375
# pop + 4.074
# pop + 16294.27
# pop + 7719.729
# pop + 7990.926
# total  : 186105.45099999997
# End
# Eastern Asia
# China, Hong Kong SAR
# pop + 7428.887
# pop + 632.418
# pop + 23694.089
# pop + 25610.672
# pop + 127185.332
# pop + 3121.772
# pop + 51164.435
# total  : 238837.60499999998
# End
# South-Central Asia
# Kazakhstan
# pop + 18403.86
# pop + 6132.932
# pop + 9107.211
# pop + 5851.466
# pop + 32364.996
# pop + 36373.176
# pop + 166368.149
# pop + 817.054
# pop + 82011.735
# pop + 444.259
# pop + 29624.035
# pop + 20950.041
# total  : 408448.91400000005
# End
# South-Eastern Asia
# Brunei Darussalam
# pop + 434.076
# pop + 16245.729
# pop + 6961.21
# pop + 32042.458
# pop + 53855.735
# pop + 5791.901
# pop + 1324.094
# total  : 116655.203
# End
# Western Asia
# Armenia
# pop + 2934.152
# pop + 9923.914
# pop + 1566.993
# pop + 1189.085
# pop + 3907.131
# pop + 8452.841
# pop + 9903.802
# pop + 4197.128
# pop + 6093.509
# pop + 4829.946
# pop + 2694.849
# pop + 5052.776
# pop + 18284.407
# pop + 9541.615
# total  : 88572.148
# End
# Eastern Europe
# Belarus
# pop + 9452.113
# pop + 7036.848
# pop + 10625.25
# pop + 9688.847
# pop + 4041.065
# pop + 19580.634
# pop + 5449.816
# total  : 65874.573
# End
# Northern Europe
# Channel Islands
# pop + 166.083
# pop + 5754.356
# pop + 1306.788
# pop + 49.489
# pop + 5542.517
# pop + 337.78
# pop + 4803.748
# pop + 84.831
# pop + 1929.938
# pop + 2876.475
# pop + 5353.363
# pop + 9982.709
# total  : 38188.077
# End
# Southern Europe
# Albania
# pop + 2934.363
# pop + 76.953
# pop + 3503.554
# pop + 4164.783
# pop + 34.733
# pop + 11142.161
# pop + 0.801
# pop + 432.089
# pop + 629.219
# pop + 10291.196
# pop + 33.557
# pop + 8762.027
# pop + 2081.26
# pop + 2085.051
# total  : 46171.747
# End
# Western Europe
# Austria
# pop + 8751.82
# pop + 11498.519
# pop + 38.155
# pop + 590.321
# pop + 38.897
# pop + 17084.459
# pop + 8544.034
# total  : 46546.205
# End
# Caribbean
# Anguilla
# pop + 15.045
# pop + 103.05
# pop + 105.67
# pop + 399.285
# pop + 286.388
# pop + 31.719
# pop + 25.702
# pop + 62.348
# pop + 161.577
# pop + 74.308
# pop + 108.339
# pop + 449.173
# pop + 2898.677
# pop + 385.065
# pop + 5.203
# pop + 3659.007
# pop + 55.85
# pop + 179.667
# pop + 110.2
# pop + 40.552
# pop + 1372.598
# pop + 35.963
# pop + 104.914
# total  : 10670.300000000001
# End
# Central America
# Belize
# pop + 382.444
# pop + 4953.199
# pop + 6411.558
# pop + 17245.346
# pop + 9417.167
# pop + 6284.757
# pop + 4162.618
# total  : 48857.089
# End
# South America
# Bolivia (Plurinational State of)
# pop + 11215.674
# pop + 18197.209
# pop + 16863.425
# pop + 2.922
# pop + 289.763
# pop + 782.225
# pop + 6896.908
# pop + 32551.815
# pop + 568.301
# pop + 3469.551
# pop + 32381.221
# total  : 123219.01400000002
# End
# Melanesia
# Fiji
# pop + 912.241
# pop + 279.821
# pop + 623.281
# pop + 282.117
# total  : 2097.46
# End
# Micronesia
# Marshall Islands
# pop + 53.167
# pop + 11.312
# pop + 21.964
# total  : 86.443
# End
# Polynesia
# American Samoa
# pop + 55.679
# pop + 17.411
# pop + 1.624
# pop + 1.319
# pop + 11.287
# pop + 11.683
# total  : 99.00300000000001
# End

# %%
branchvalues from plotly.subplots import make_subplots
fig = make_subplots(1, 2, specs=[[{"type": "domain"}, {"type": "domain"}]],)

fig.add_trace(go.Sunburst(
    labels=stubData['character'],
    parents=stubData['parent'],
    values=stubData['value'],
    branchvalues='total',
    marker=dict(
        colors=stubData['urban'],
        colorscale='rdylgn_r',
        cmid=55.3,
        colorbar=dict(bgcolor="#ffffff", title= "Urban percent", )
        ),
    hovertemplate='<b>%{label} </b> <br> Population: %{value} thousands<br> Urban Percent: %{color:.2f}',
    name='',
    maxdepth=2
    ), 1, 1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="050928e1-12c0-46d1-8380-e31443a8ae09" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("050928e1-12c0-46d1-8380-e31443a8ae09")) {
#                     Plotly.newPlot(
#                         '050928e1-12c0-46d1-8380-e31443a8ae09',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 0.45], "y": [0.0, 1.0]}, "hovertemplate": "<b>%{label} </b> <br> Population: %{value} thousands<br> Urban Percent: %{color:.2f}", "labels": ["World", "Africa", "Eastern Africa", "Eastern Africa smallest country", "Burundi", "Comoros", "Djibouti", "Eritrea", "Ethiopia", "Kenya", "Madagascar", "Malawi", "Mauritius", "Mayotte", "Mozambique", "R\u00e9union", "Rwanda", "Seychelles", "Somalia", "South Sudan", "Uganda", "United Republic of Tanzania", "Zambia", "Zimbabwe", "Middle Africa", "Angola", "Cameroon", "Middle Africa smallest country", "Central African Republic", "Chad", "Congo", "Democratic Republic of the Congo", "Equatorial Guinea", "Gabon", "Sao Tome and Principe", "Northern Africa", "Algeria", "Egypt", "Northern Africa smallest country", "Libya", "Morocco", "Sudan", "Tunisia", "Western Sahara", "Southern Africa", "Southern Africa smallest country", "Botswana", "Lesotho", "Namibia", "South Africa", "Swaziland", "Western Africa", "Western Africa smallest country", "Benin", "Burkina Faso", "Cabo Verde", "C\u00f4te d'Ivoire", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Liberia", "Mali", "Mauritania", "Niger", "Nigeria", "Saint Helena", "Senegal", "Sierra Leone", "Togo", "Asia", "Eastern Asia", "China", "Eastern Asia smallest country", "China, Hong Kong SAR", "China, Macao SAR", "China, Taiwan Province of China", "Dem. People's Republic of Korea", "Japan", "Mongolia", "Republic of Korea", "South-Central Asia", "South-Central Asia smallest country", "Kazakhstan", "Kyrgyzstan", "Tajikistan", "Turkmenistan", "Uzbekistan", "Afghanistan", "Bangladesh", "Bhutan", "India", "Iran (Islamic Republic of)", "Maldives", "Nepal", "Pakistan", "Sri Lanka", "South-Eastern Asia", "South-Eastern Asia smallest country", "Brunei Darussalam", "Cambodia", "Indonesia", "Lao People's Democratic Republic", "Malaysia", "Myanmar", "Philippines", "Singapore", "Thailand", "Timor-Leste", "Viet Nam", "Western Asia", "Western Asia smallest country", "Armenia", "Azerbaijan", "Bahrain", "Cyprus", "Georgia", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Qatar", "Saudi Arabia", "State of Palestine", "Syrian Arab Republic", "Turkey", "United Arab Emirates", "Yemen", "Europe", "Eastern Europe", "Eastern Europe smallest country", "Belarus", "Bulgaria", "Czechia", "Hungary", "Poland", "Republic of Moldova", "Romania", "Russian Federation", "Slovakia", "Ukraine", "Northern Europe", "Northern Europe smallest country", "Channel Islands", "Denmark", "Estonia", "Faeroe Islands", "Finland", "Iceland", "Ireland", "Isle of Man", "Latvia", "Lithuania", "Norway", "Sweden", "United Kingdom", "Southern Europe", "Southern Europe smallest country", "Albania", "Andorra", "Bosnia and Herzegovina", "Croatia", "Gibraltar", "Greece", "Holy See", "Italy", "Malta", "Montenegro", "Portugal", "San Marino", "Serbia", "Slovenia", "Spain", "TFYR Macedonia", "Western Europe", "Western Europe smallest country", "Austria", "Belgium", "France", "Germany", "Liechtenstein", "Luxembourg", "Monaco", "Netherlands", "Switzerland", "Latin america and the caribbean", "Caribbean", "Caribbean smallest country", "Anguilla", "Antigua and Barbuda", "Aruba", "Bahamas", "Barbados", "British Virgin Islands", "Caribbean Netherlands", "Cayman Islands", "Cuba", "Cura\u00e7ao", "Dominica", "Dominican Republic", "Grenada", "Guadeloupe", "Haiti", "Jamaica", "Martinique", "Montserrat", "Puerto Rico", "Saint Kitts and Nevis", "Saint Lucia", "Saint Vincent and the Grenadines", "Sint Maarten (Dutch part)", "Trinidad and Tobago", "Turks and Caicos Islands", "United States Virgin Islands", "Central America", "Central America smallest country", "Belize", "Costa Rica", "El Salvador", "Guatemala", "Honduras", "Mexico", "Nicaragua", "Panama", "South America", "Argentina", "South America smallest country", "Bolivia (Plurinational State of)", "Brazil", "Chile", "Colombia", "Ecuador", "Falkland Islands (Malvinas)", "French Guiana", "Guyana", " ...
